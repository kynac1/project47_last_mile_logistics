# %%
import json
import os

# %%
data = {}
for fname in os.listdir():
    name, ext = os.path.splitext(fname)
    if ext == ".json":
        fields = name.split('_')
        if fields[0] == 'constant':
            fields[1] = int(fields[1])
            fields[2] = int(fields[2])
            fields[3] = int(fields[3])
            fields[4] = int(fields[4])
            with open(fname, 'r') as f:
                data[tuple(fields[1:6])] = json.load(f)
print(list(data.keys()))
# Out:
# [(50, 3, 1, 1, 'estimate'), (50, 3, 1, 1, 'wait'), (50, 3, 1, 2, 'wait'), (50, 3, 1, 3, 'wait'), (50, 3, 2, 1, 'estimate'), (50, 3, 2, 1, 'wait'), (50, 3, 2, 2, 'wait'), (50, 3, 2, 3, 'wait'), (50, 3, 4, 1, 'estimate'), (50, 3, 4, 1, 'wait'), (50, 3, 4, 2, 'wait'), (50, 3, 4, 3, 'wait'), (50, 3, 8, 1, 'estimate'), (50, 3, 8, 1, 'wait'), (50, 3, 8, 2, 'wait'), (50, 3, 8, 3, 'wait'), (50, 5, 1, 1, 'estimate'), (50, 5, 1, 1, 'wait'), (50, 5, 1, 2, 'wait'), (50, 5, 1, 3, 'wait'), (50, 5, 2, 1, 'estimate'), (50, 5, 2, 1, 'wait'), (50, 5, 2, 3, 'wait'), (50, 5, 4, 1, 'estimate'), (50, 5, 4, 1, 'wait'), (50, 7, 8, 1, 'wait'), (50, 5, 4, 2, 'wait'), (50, 5, 4, 3, 'wait'), (50, 5, 8, 1, 'estimate'), (50, 5, 8, 1, 'wait'), (50, 5, 8, 2, 'wait'), (50, 7, 1, 1, 'estimate'), (50, 7, 1, 1, 'wait'), (50, 7, 1, 2, 'wait'), (50, 7, 1, 3, 'wait'), (50, 7, 2, 1, 'estimate'), (50, 7, 2, 1, 'wait'), (50, 7, 2, 2, 'wait'), (50, 7, 2, 3, 'wait'), (50, 7, 4, 1, 'estimate'), (50, 7, 4, 1, 'wait'), (50, 7, 4, 2, 'wait'), (50, 7, 8, 1, 'estimate'), (50, 7, 8, 2, 'wait'), (50, 9, 1, 1, 'estimate'), (50, 9, 1, 1, 'wait'), (50, 9, 1, 2, 'wait'), (50, 9, 1, 3, 'wait'), (50, 9, 2, 1, 'estimate'), (50, 9, 2, 1, 'wait'), (50, 9, 2, 2, 'wait'), (50, 9, 2, 3, 'wait'), (50, 9, 4, 1, 'estimate'), (50, 9, 4, 1, 'wait'), (50, 9, 4, 3, 'wait'), (50, 9, 8, 1, 'estimate'), (50, 9, 8, 1, 'wait'), (50, 9, 8, 3, 'wait')]

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

# %%
packages_over_time = {}
for k,v in data.items():
    packages_over_time[k] = []
    for i in range(len(v)-1):
        packages_over_time[k].append(v[i+1]['number_of_packages'] - (v[i]['number_of_packages'] - len(v[i]['delivered_packages']['days_taken'])))

# %%
plt.cla()
for k,v in packages_over_time.items():
    if k[4] == 'wait':
        plt.plot(v, label=str(k))
plt.legend()
plt.show()

# %%
packages_over_time = {}
for k,v in data.items():
    packages_over_time[k] = [len(d['delivered_packages']['days_taken']) for d in v]

# %%
plt.cla()
for k,v in packages_over_time.items():
    if k[4] == 'wait':
        plt.plot(v, label=str(k))
plt.legend()
plt.show()

# %%
packages_over_time = {}
for k,v in data.items():
    packages_over_time[k] = [d['number_of_packages'] for d in v]
plt.cla()
for k,v in packages_over_time.items():
    if k[4] != 'wait' and k[2] == 8:
        plt.plot(v, label=str(k))
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
q = pd.DataFrame(data)
q
# Out:
# packages': 310, 'number...
# 34  {'day': 34, 'number_of_packages': 315, 'number...
# 35  {'day': 35, 'number_of_packages': 315, 'number...
# 36  {'day': 36, 'number_of_packages': 325, 'number...
# 37  {'day': 37, 'number_of_packages': 328, 'number...
# 38  {'day': 38, 'number_of_packages': 332, 'number...
# 39  {'day': 39, 'number_of_packages': 343, 'number...
# 40  {'day': 40, 'number_of_packages': 354, 'number...
# 41  {'day': 41, 'number_of_packages': 366, 'number...
# 42  {'day': 42, 'number_of_packages': 356, 'number...
# 43  {'day': 43, 'number_of_packages': 355, 'number...
# 44  {'day': 44, 'number_of_packages': 355, 'number...
# 45  {'day': 45, 'number_of_packages': 369, 'number...
# 46  {'day': 46, 'number_of_packages': 368, 'number...
# 47  {'day': 47, 'number_of_packages': 364, 'number...
# 48  {'day': 48, 'number_of_packages': 358, 'number...
# 49  {'day': 49, 'number_of_packages': 365, 'number...
# 50  {'day': 50, 'number_of_packages': 363, 'number...
# 51  {'day': 51, 'number_of_packages': 369, 'number...
# 52  {'day': 52, 'number_of_packages': 378, 'number...
# 53  {'day': 53, 'number_of_packages': 382, 'number...
# 54  {'day': 54, 'number_of_packages': 389, 'number...
# 55  {'day': 55, 'number_of_packages': 384, 'number...
# 56  {'day': 56, 'number_of_packages': 395, 'number...
# 57  {'day': 57, 'number_of_packages': 396, 'number...
# 58  {'day': 58, 'number_of_packages': 400, 'number...
# 59  {'day': 59, 'number_of_packages': 407, 'number...
#
#                                                        \
#
#
#
#                                                  wait
# 0   {'day': 0, 'number_of_packages': 50, 'number_o...
# 1   {'day': 1, 'number_of_packages': 81, 'number_o...
# 2   {'day': 2, 'number_of_packages': 103, 'number_...
# 3   {'day': 3, 'number_of_packages': 116, 'number_...
# 4   {'day': 4, 'number_of_packages': 148, 'number_...
# 5   {'day': 5, 'number_of_packages': 159, 'number_...
# 6   {'day': 6, 'number_of_packages': 173, 'number_...
# 7   {'day': 7, 'number_of_packages': 192, 'number_...
# 8   {'day': 8, 'number_of_packages': 199, 'number_...
# 9   {'day': 9, 'number_of_packages': 217, 'number_...
# 10  {'day': 10, 'number_of_packages': 220, 'number...
# 11  {'day': 11, 'number_of_packages': 220, 'number...
# 12  {'day': 12, 'number_of_packages': 220, 'number...
# 13  {'day': 13, 'number_of_packages': 237, 'number...
# 14  {'day': 14, 'number_of_packages': 246, 'number...
# 15  {'day': 15, 'number_of_packages': 251, 'number...
# 16  {'day': 16, 'number_of_packages': 244, 'number...
# 17  {'day': 17, 'number_of_packages': 253, 'number...
# 18  {'day': 18, 'number_of_packages': 256, 'number...
# 19  {'day': 19, 'number_of_packages': 259, 'number...
# 20  {'day': 20, 'number_of_packages': 257, 'number...
# 21  {'day': 21, 'number_of_packages': 263, 'number...
# 22  {'day': 22, 'number_of_packages': 257, 'number...
# 23  {'day': 23, 'number_of_packages': 273, 'number...
# 24  {'day': 24, 'number_of_packages': 273, 'number...
# 25  {'day': 25, 'number_of_packages': 278, 'number...
# 26  {'day': 26, 'number_of_packages': 286, 'number...
# 27  {'day': 27, 'number_of_packages': 289, 'number...
# 28  {'day': 28, 'number_of_packages': 297, 'number...
# 29  {'day': 29, 'number_of_packages': 305, 'number...
# 30  {'day': 30, 'number_of_packages': 309, 'number...
# 31  {'day': 31, 'number_of_packages': 309, 'number...
# 32  {'day': 32, 'number_of_packages': 301, 'number...
# 33  {'day': 33, 'number_of_packages': 298, 'number...
# 34  {'day': 34, 'number_of_packages': 299, 'number...
# 35  {'day': 35, 'number_of_packages': 306, 'number...
# 36  {'day': 36, 'number_of_packages': 313, 'number...
# 37  {'day': 37, 'number_of_packages': 313, 'number...
# 38  {'day': 38, 'number_of_packages': 320, 'number...
# 39  {'day': 39, 'number_of_packages': 330, 'number...
# 40  {'day': 40, 'number_of_packages': 343, 'number...
# 41  {'day': 41, 'number_of_packages': 357, 'number...
# 42  {'day': 42, 'number_of_packages': 343, 'number...
# 43  {'day': 43, 'number_of_packages': 347, 'number...
# 44  {'day': 44, 'number_of_packages': 348, 'number...
# 45  {'day': 45, 'number_of_packages': 356, 'number...
# 46  {'day': 46, 'number_of_packages': 352, 'number...
# 47  {'day': 47, 'number_of_packages': 347, 'number...
# 48  {'day': 48, 'number_of_packages': 352, 'number...
# 49  {'day': 49, 'number_of_packages': 353, 'number...
# 50  {'day': 50, 'number_of_packages': 349, 'number...
# 51  {'day': 51, 'number_of_packages': 353, 'number...
# 52  {'day': 52, 'number_of_packages': 359, 'number...
# 53  {'day': 53, 'number_of_packages': 365, 'number...
# 54  {'day': 54, 'number_of_packages': 365, 'number...
# 55  {'day': 55, 'number_of_packages': 364, 'number...
# 56  {'day': 56, 'number_of_packages': 373, 'number...
# 57  {'day': 57, 'number_of_packages': 372, 'number...
# 58  {'day': 58, 'number_of_packages': 367, 'number...
# 59  {'day': 59, 'number_of_packages': 378, 'number...
#
#                                                        \
#
#
#                                                     3
#                                                  wait
# 0   {'day': 0, 'number_of_packages': 150, 'number_...
# 1   {'day': 1, 'number_of_packages': 237, 'number_...
# 2   {'day': 2, 'number_of_packages': 303, 'number_...
# 3   {'day': 3, 'number_of_packages': 348, 'number_...
# 4   {'day': 4, 'number_of_packages': 393, 'number_...
# 5   {'day': 5, 'number_of_packages': 426, 'number_...
# 6   {'day': 6, 'number_of_packages': 456, 'number_...
# 7   {'day': 7, 'number_of_packages': 483, 'number_...
# 8   {'day': 8, 'number_of_packages': 465, 'number_...
# 9   {'day': 9, 'number_of_packages': 513, 'number_...
# 10  {'day': 10, 'number_of_packages': 507, 'number...
# 11  {'day': 11, 'number_of_packages': 510, 'number...
# 12  {'day': 12, 'number_of_packages': 513, 'number...
# 13  {'day': 13, 'number_of_packages': 549, 'number...
# 14  {'day': 14, 'number_of_packages': 540, 'number...
# 15  {'day': 15, 'number_of_packages': 594, 'number...
# 16  {'day': 16, 'number_of_packages': 597, 'number...
# 17  {'day': 17, 'number_of_packages': 618, 'number...
# 18  {'day': 18, 'number_of_packages': 582, 'number...
# 19  {'day': 19, 'number_of_packages': 582, 'number...
# 20  {'day': 20, 'number_of_packages': 600, 'number...
# 21  {'day': 21, 'number_of_packages': 609, 'number...
# 22  {'day': 22, 'number_of_packages': 606, 'number...
# 23  {'day': 23, 'number_of_packages': 615, 'number...
# 24  {'day': 24, 'number_of_packages': 618, 'number...
# 25  {'day': 25, 'number_of_packages': 633, 'number...
# 26  {'day': 26, 'number_of_packages': 675, 'number...
# 27  {'day': 27, 'number_of_packages': 675, 'number...
# 28  {'day': 28, 'number_of_packages': 636, 'number...
# 29  {'day': 29, 'number_of_packages': 633, 'number...
# 30  {'day': 30, 'number_of_packages': 654, 'number...
# 31  {'day': 31, 'number_of_packages': 648, 'number...
# 32  {'day': 32, 'number_of_packages': 645, 'number...
# 33  {'day': 33, 'number_of_packages': 684, 'number...
# 34  {'day': 34, 'number_of_packages': 654, 'number...
# 35  {'day': 35, 'number_of_packages': 672, 'number...
# 36  {'day': 36, 'number_of_packages': 666, 'number...
# 37  {'day': 37, 'number_of_packages': 666, 'number...
# 38  {'day': 38, 'number_of_packages': 693, 'number...
# 39  {'day': 39, 'number_of_packages': 702, 'number...
# 40  {'day': 40, 'number_of_packages': 696, 'number...
# 41  {'day': 41, 'number_of_packages': 681, 'number...
# 42  {'day': 42, 'number_of_packages': 696, 'number...
# 43  {'day': 43, 'number_of_packages': 678, 'number...
# 44  {'day': 44, 'number_of_packages': 642, 'number...
# 45  {'day': 45, 'number_of_packages': 627, 'number...
# 46  {'day': 46, 'number_of_packages': 666, 'number...
# 47  {'day': 47, 'number_of_packages': 654, 'number...
# 48  {'day': 48, 'number_of_packages': 630, 'number...
# 49  {'day': 49, 'number_of_packages': 645, 'number...
# 50  {'day': 50, 'number_of_packages': 639, 'number...
# 51  {'day': 51, 'number_of_packages': 660, 'number...
# 52  {'day': 52, 'number_of_packages': 693, 'number...
# 53  {'day': 53, 'number_of_packages': 699, 'number...
# 54  {'day': 54, 'number_of_packages': 675, 'number...
# 55  {'day': 55, 'number_of_packages': 690, 'number...
# 56  {'day': 56, 'number_of_packages': 750, 'number...
# 57  {'day': 57, 'number_of_packages': 741, 'number...
# 58  {'day': 58, 'number_of_packages': 783, 'number...
# 59  {'day': 59, 'number_of_packages': 759, 'number...
#
#                                                        \
#
#                                                     8
#                                                     1
#                                              estimate
# 0   {'day': 0, 'number_of_packages': 50, 'number_o...
# 1   {'day': 1, 'number_of_packages': 76, 'number_o...
# 2   {'day': 2, 'number_of_packages': 92, 'number_o...
# 3   {'day': 3, 'number_of_packages': 108, 'number_...
# 4   {'day': 4, 'number_of_packages': 123, 'number_...
# 5   {'day': 5, 'number_of_packages': 135, 'number_...
# 6   {'day': 6, 'number_of_packages': 141, 'number_...
# 7   {'day': 7, 'number_of_packages': 143, 'number_...
# 8   {'day': 8, 'number_of_packages': 153, 'number_...
# 9   {'day': 9, 'number_of_packages': 158, 'number_...
# 10  {'day': 10, 'number_of_packages': 161, 'number...
# 11  {'day': 11, 'number_of_packages': 157, 'number...
# 12  {'day': 12, 'number_of_packages': 165, 'number...
# 13  {'day': 13, 'number_of_packages': 168, 'number...
# 14  {'day': 14, 'number_of_packages': 158, 'number...
# 15  {'day': 15, 'number_of_packages': 175, 'number...
# 16  {'day': 16, 'number_of_packages': 174, 'number...
# 17  {'day': 17, 'number_of_packages': 177, 'number...
# 18  {'day': 18, 'number_of_packages': 184, 'number...
# 19  {'day': 19, 'number_of_packages': 180, 'number...
# 20  {'day': 20, 'number_of_packages': 188, 'number...
# 21  {'day': 21, 'number_of_packages': 188, 'number...
# 22  {'day': 22, 'number_of_packages': 189, 'number...
# 23  {'day': 23, 'number_of_packages': 192, 'number...
# 24  {'day': 24, 'number_of_packages': 217, 'number...
# 25  {'day': 25, 'number_of_packages': 219, 'number...
# 26  {'day': 26, 'number_of_packages': 218, 'number...
# 27  {'day': 27, 'number_of_packages': 235, 'number...
# 28  {'day': 28, 'number_of_packages': 244, 'number...
# 29  {'day': 29, 'number_of_packages': 238, 'number...
# 30  {'day': 30, 'number_of_packages': 250, 'number...
# 31  {'day': 31, 'number_of_packages': 246, 'number...
# 32  {'day': 32, 'number_of_packages': 250, 'number...
# 33  {'day': 33, 'number_of_packages': 262, 'number...
# 34  {'day': 34, 'number_of_packages': 271, 'number...
# 35  {'day': 35, 'number_of_packages': 275, 'number...
# 36  {'day': 36, 'number_of_packages': 279, 'number...
# 37  {'day': 37, 'number_of_packages': 291, 'number...
# 38  {'day': 38, 'number_of_packages': 282, 'number...
# 39  {'day': 39, 'number_of_packages': 283, 'number...
# 40  {'day': 40, 'number_of_packages': 294, 'number...
# 41  {'day': 41, 'number_of_packages': 285, 'number...
# 42  {'day': 42, 'number_of_packages': 292, 'number...
# 43  {'day': 43, 'number_of_packages': 300, 'number...
# 44  {'day': 44, 'number_of_packages': 307, 'number...
# 45  {'day': 45, 'number_of_packages': 303, 'number...
# 46  {'day': 46, 'number_of_packages': 312, 'number...
# 47  {'day': 47, 'number_of_packages': 318, 'number...
# 48  {'day': 48, 'number_of_packages': 328, 'number...
# 49  {'day': 49, 'number_of_packages': 332, 'number...
# 50  {'day': 50, 'number_of_packages': 330, 'number...
# 51  {'day': 51, 'number_of_packages': 344, 'number...
# 52  {'day': 52, 'number_of_packages': 346, 'number...
# 53  {'day': 53, 'number_of_packages': 344, 'number...
# 54  {'day': 54, 'number_of_packages': 343, 'number...
# 55  {'day': 55, 'number_of_packages': 348, 'number...
# 56  {'day': 56, 'number_of_packages': 348, 'number...
# 57  {'day': 57, 'number_of_packages': 309, 'number...
# 58  {'day': 58, 'number_of_packages': 324, 'number...
# 59  {'day': 59, 'number_of_packages': 308, 'number...
#
#                                                        \
#
#
#
#                                                  wait
# 0   {'day': 0, 'number_of_packages': 50, 'number_o...
# 1   {'day': 1, 'number_of_packages': 76, 'number_o...
# 2   {'day': 2, 'number_of_packages': 92, 'number_o...
# 3   {'day': 3, 'number_of_packages': 106, 'number_...
# 4   {'day': 4, 'number_of_packages': 120, 'number_...
# 5   {'day': 5, 'number_of_packages': 131, 'number_...
# 6   {'day': 6, 'number_of_packages': 137, 'number_...
# 7   {'day': 7, 'number_of_packages': 139, 'number_...
# 8   {'day': 8, 'number_of_packages': 147, 'number_...
# 9   {'day': 9, 'number_of_packages': 155, 'number_...
# 10  {'day': 10, 'number_of_packages': 164, 'number...
# 11  {'day': 11, 'number_of_packages': 156, 'number...
# 12  {'day': 12, 'number_of_packages': 162, 'number...
# 13  {'day': 13, 'number_of_packages': 164, 'number...
# 14  {'day': 14, 'number_of_packages': 157, 'number...
# 15  {'day': 15, 'number_of_packages': 175, 'number...
# 16  {'day': 16, 'number_of_packages': 169, 'number...
# 17  {'day': 17, 'number_of_packages': 174, 'number...
# 18  {'day': 18, 'number_of_packages': 180, 'number...
# 19  {'day': 19, 'number_of_packages': 177, 'number...
# 20  {'day': 20, 'number_of_packages': 187, 'number...
# 21  {'day': 21, 'number_of_packages': 186, 'number...
# 22  {'day': 22, 'number_of_packages': 198, 'number...
# 23  {'day': 23, 'number_of_packages': 193, 'number...
# 24  {'day': 24, 'number_of_packages': 200, 'number...
# 25  {'day': 25, 'number_of_packages': 206, 'number...
# 26  {'day': 26, 'number_of_packages': 202, 'number...
# 27  {'day': 27, 'number_of_packages': 217, 'number...
# 28  {'day': 28, 'number_of_packages': 218, 'number...
# 29  {'day': 29, 'number_of_packages': 222, 'number...
# 30  {'day': 30, 'number_of_packages': 229, 'number...
# 31  {'day': 31, 'number_of_packages': 229, 'number...
# 32  {'day': 32, 'number_of_packages': 237, 'number...
# 33  {'day': 33, 'number_of_packages': 243, 'number...
# 34  {'day': 34, 'number_of_packages': 240, 'number...
# 35  {'day': 35, 'number_of_packages': 246, 'number...
# 36  {'day': 36, 'number_of_packages': 230, 'number...
# 37  {'day': 37, 'number_of_packages': 229, 'number...
# 38  {'day': 38, 'number_of_packages': 234, 'number...
# 39  {'day': 39, 'number_of_packages': 249, 'number...
# 40  {'day': 40, 'number_of_packages': 243, 'number...
# 41  {'day': 41, 'number_of_packages': 246, 'number...
# 42  {'day': 42, 'number_of_packages': 250, 'number...
# 43  {'day': 43, 'number_of_packages': 251, 'number...
# 44  {'day': 44, 'number_of_packages': 259, 'number...
# 45  {'day': 45, 'number_of_packages': 267, 'number...
# 46  {'day': 46, 'number_of_packages': 279, 'number...
# 47  {'day': 47, 'number_of_packages': 288, 'number...
# 48  {'day': 48, 'number_of_packages': 297, 'number...
# 49  {'day': 49, 'number_of_packages': 297, 'number...
# 50  {'day': 50, 'number_of_packages': 299, 'number...
# 51  {'day': 51, 'number_of_packages': 305, 'number...
# 52  {'day': 52, 'number_of_packages': 315, 'number...
# 53  {'day': 53, 'number_of_packages': 313, 'number...
# 54  {'day': 54, 'number_of_packages': 310, 'number...
# 55  {'day': 55, 'number_of_packages': 307, 'number...
# 56  {'day': 56, 'number_of_packages': 308, 'number...
# 57  {'day': 57, 'number_of_packages': 322, 'number...
# 58  {'day': 58, 'number_of_packages': 331, 'number...
# 59  {'day': 59, 'number_of_packages': 345, 'number...
#
#
#
#
#                                                     3
#                                                  wait
# 0   {'day': 0, 'number_of_packages': 150, 'number_...
# 1   {'day': 1, 'number_of_packages': 237, 'number_...
# 2   {'day': 2, 'number_of_packages': 276, 'number_...
# 3   {'day': 3, 'number_of_packages': 318, 'number_...
# 4   {'day': 4, 'number_of_packages': 333, 'number_...
# 5   {'day': 5, 'number_of_packages': 378, 'number_...
# 6   {'day': 6, 'number_of_packages': 396, 'number_...
# 7   {'day': 7, 'number_of_packages': 384, 'number_...
# 8   {'day': 8, 'number_of_packages': 399, 'number_...
# 9   {'day': 9, 'number_of_packages': 435, 'number_...
# 10  {'day': 10, 'number_of_packages': 399, 'number...
# 11  {'day': 11, 'number_of_packages': 387, 'number...
# 12  {'day': 12, 'number_of_packages': 414, 'number...
# 13  {'day': 13, 'number_of_packages': 399, 'number...
# 14  {'day': 14, 'number_of_packages': 426, 'number...
# 15  {'day': 15, 'number_of_packages': 444, 'number...
# 16  {'day': 16, 'number_of_packages': 459, 'number...
# 17  {'day': 17, 'number_of_packages': 441, 'number...
# 18  {'day': 18, 'number_of_packages': 438, 'number...
# 19  {'day': 19, 'number_of_packages': 456, 'number...
# 20  {'day': 20, 'number_of_packages': 450, 'number...
# 21  {'day': 21, 'number_of_packages': 450, 'number...
# 22  {'day': 22, 'number_of_packages': 453, 'number...
# 23  {'day': 23, 'number_of_packages': 456, 'number...
# 24  {'day': 24, 'number_of_packages': 462, 'number...
# 25  {'day': 25, 'number_of_packages': 480, 'number...
# 26  {'day': 26, 'number_of_packages': 471, 'number...
# 27  {'day': 27, 'number_of_packages': 462, 'number...
# 28  {'day': 28, 'number_of_packages': 447, 'number...
# 29  {'day': 29, 'number_of_packages': 447, 'number...
# 30  {'day': 30, 'number_of_packages': 423, 'number...
# 31  {'day': 31, 'number_of_packages': 441, 'number...
# 32  {'day': 32, 'number_of_packages': 447, 'number...
# 33  {'day': 33, 'number_of_packages': 432, 'number...
# 34  {'day': 34, 'number_of_packages': 459, 'number...
# 35  {'day': 35, 'number_of_packages': 477, 'number...
# 36  {'day': 36, 'number_of_packages': 471, 'number...
# 37  {'day': 37, 'number_of_packages': 495, 'number...
# 38  {'day': 38, 'number_of_packages': 534, 'number...
# 39  {'day': 39, 'number_of_packages': 525, 'number...
# 40  {'day': 40, 'number_of_packages': 492, 'number...
# 41  {'day': 41, 'number_of_packages': 489, 'number...
# 42  {'day': 42, 'number_of_packages': 492, 'number...
# 43  {'day': 43, 'number_of_packages': 456, 'number...
# 44  {'day': 44, 'number_of_packages': 450, 'number...
# 45  {'day': 45, 'number_of_packages': 489, 'number...
# 46  {'day': 46, 'number_of_packages': 498, 'number...
# 47  {'day': 47, 'number_of_packages': 492, 'number...
# 48  {'day': 48, 'number_of_packages': 483, 'number...
# 49  {'day': 49, 'number_of_packages': 462, 'number...
# 50  {'day': 50, 'number_of_packages': 495, 'number...
# 51  {'day': 51, 'number_of_packages': 525, 'number...
# 52  {'day': 52, 'number_of_packages': 522, 'number...
# 53  {'day': 53, 'number_of_packages': 507, 'number...
# 54  {'day': 54, 'number_of_packages': 528, 'number...
# 55  {'day': 55, 'number_of_packages': 579, 'number...
# 56  {'day': 56, 'number_of_packages': 567, 'number...
# 57  {'day': 57, 'number_of_packages': 582, 'number...
# 58  {'day': 58, 'number_of_packages': 555, 'number...
# 59  {'day': 59, 'number_of_packages': 534, 'number...
#
# [60 rows x 58 columns]
