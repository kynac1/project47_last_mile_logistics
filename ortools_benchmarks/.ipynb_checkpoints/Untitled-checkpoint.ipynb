# %%
using DataFrames, DataFramesMeta

# %%
using AlgebraOfGraphics

# %%
using AbstractPlotting

# %%
using CairoMakie

# %%
using AlgebraOfGraphics: smooth

# %%
df = DataFrame(
    fss = String[],
    lsm = String[],
    iter = Int[],
    obj = Int[],
    time = Int[],
)
# Out:
# 0×5 DataFrame

# %%
fss = ""
lsm = ""
for line in readlines("full_problem.log")
    if line[1:3] == "FSS"
        fss = line[7:end]
    elseif line[1:3] == "LSM"
        lsm = line[7:end]
    else
        reg = r"Solution #(\d+) \((\d+),.+time = (\d+)"
        if occursin(reg, line)
            m = match(reg, line)
            push!(df,(
                fss,
                lsm,
                parse(Int, m.captures[1]),
                parse(Int, m.captures[2]),
                parse(Int, m.captures[3]),
            ))
        end
    end
end

# %%
q = @linq df |>
    where(:iter .== 0)
data(q) * style(:obj, :fss) * spec(Scatter) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   1 Child Scene:
#     └ Scene (490px, 403px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
q = @linq df |>
    where(:iter .== 0) |>
    where(:obj .< 4e6)
data(q) * style(:time, :obj, color=:fss => categorical) * spec(Scatter) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   2 Child Scenes:
#     ├ Scene (345px, 403px)
#     └ Scene (402px, 245px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
q = @linq df |>
    where(:fss .== "LOCAL_CHEAPEST_INSERTION")
newstyle = style(markersize = :obj) * spec(markersize = (10, 10))
data(q) * style(:time, :obj, color=:lsm => categorical) * (spec(Scatter)*newstyle) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   2 Child Scenes:
#     ├ Scene (458px, 403px)
#     └ Scene (289px, 191px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
df2 = DataFrame(
    fss = String[],
    lsm = String[],
    iter = Int[],
    obj = Int[],
    time = Int[],
)
# Out:
# 0×5 DataFrame

# %%
fss = ""
lsm = ""
for line in readlines("rerouting.log")
    if length(line) < 3
        continue
    end
    if line[1:3] == "FSS"
        fss = line[7:end]
    elseif line[1:3] == "LSM"
        lsm = line[7:end]
    else
        reg = r"Solution #(\d+) \((\d+),.+time = (\d+)"
        if occursin(reg, line)
            m = match(reg, line)
            push!(df2,(
                fss,
                lsm,
                parse(Int, m.captures[1]),
                parse(Int, m.captures[2]),
                parse(Int, m.captures[3]),
            ))
        end
    end
end

# %%
df2
# Out:
# 24441×5 DataFrame
# │ Row   │ fss                           │ lsm         │ iter  │ obj    │ time  │
# │       │ String                        │ String      │ Int64 │ Int64  │ Int64 │
# ├───────┼───────────────────────────────┼─────────────┼───────┼────────┼───────┤
# │ 1     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 0     │ 970000 │ 1     │
# │ 2     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 1     │ 960489 │ 51    │
# │ 3     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 2     │ 951104 │ 52    │
# │ 4     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 3     │ 941327 │ 53    │
# │ 5     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 4     │ 931978 │ 53    │
# │ 6     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 5     │ 921727 │ 54    │
# │ 7     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 6     │ 911920 │ 55    │
# │ 8     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 7     │ 901899 │ 57    │
# │ 9     │ ALL_UNPERFORMED               │ AUTOMATIC   │ 8     │ 891701 │ 60    │
# │ 10    │ ALL_UNPERFORMED               │ AUTOMATIC   │ 9     │ 881702 │ 61    │
# ⋮
# │ 24431 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 56    │ 492156 │ 16543 │
# │ 24432 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 57    │ 482127 │ 16705 │
# │ 24433 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 58    │ 472159 │ 16797 │
# │ 24434 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 59    │ 472158 │ 17004 │
# │ 24435 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 60    │ 472163 │ 17383 │
# │ 24436 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 61    │ 462133 │ 17479 │
# │ 24437 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 62    │ 462177 │ 18047 │
# │ 24438 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 63    │ 472249 │ 19105 │
# │ 24439 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 64    │ 482130 │ 19368 │
# │ 24440 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 65    │ 472249 │ 19380 │
# │ 24441 │ SEQUENTIAL_CHEAPEST_INSERTION │ TABU_SEARCH │ 66    │ 472250 │ 19982 │

# %%
q = @linq df2 |>
    where(:iter .== 0)
data(q) * style(:obj, :fss) * spec(Scatter) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   1 Child Scene:
#     └ Scene (490px, 403px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
q = @linq df2 |>
    where(:iter .== 0) |>
    where(:obj .< 9e5)
data(q) * style(:time, :obj, color=:fss => categorical) * spec(Scatter) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   2 Child Scenes:
#     ├ Scene (364px, 403px)
#     └ Scene (402px, 273px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
q = @linq df2 |>
    where(:fss .== "PATH_CHEAPEST_ARC") |>
    where(:time .< 5e3)
newstyle = style(markersize = :obj) * spec(markersize = (10, 10))
data(q) * style(:time, :obj, color=:lsm => categorical) * (spec(Scatter)*newstyle) |> draw
# Out:
# Scene (960px, 540px):
#   14 Plots:
#     ├ Poly{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ LineSegments{...}
#     ├ Annotations{...}
#     ├ Text{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     ├ Lines{...}
#     └ Text{...}
#   2 Child Scenes:
#     ├ Scene (458px, 403px)
#     └ Scene (289px, 191px)
# ┌ Warning: Showing scene as text. This happens because `AbstractPlotting.inline!(true)` is set.
# │ This needs to be false to show a plot in a window when in the REPL.
# └ @ AbstractPlotting /home/michael/.julia/packages/AbstractPlotting/T806p/src/display.jl:135

# %%
8000 / 1000
# Out:
# 8.0
